# %% [markdown]
# ## Goal of the Dataset
#
# The purpose of collecting this dataset is to develop a **job recommendation system** that helps job seekers find suitable roles by analyzing their past experiences, skills, and preferences. This system aims to assist job seekers in identifying the most relevant job opportunities while also supporting recruiters in finding the best candidates for their requirements.
#
# ### Purpose of Collecting the Dataset
# This dataset was collected for the purpose of **requirements classification**, where the goal is to:
# 1. **Analyze Job Requirements**: Understand the skills, experiences, and qualifications required for different roles.
# 2. **Evaluate Candidate Profiles**: Identify the suitability of candidates for specific job positions based on their profiles.
# 3. **Perform Skill Gap Analysis**: Recommend skills or certifications to help candidates align with the requirements of their desired roles.
#
# ### Objectives of the Dataset
# 1. **Personalized Job Recommendations**: Match job postings with candidates' qualifications and aspirations.
# 2. **Career Path Insights**: Provide recommendations for career progression based on historical job roles and skills.
# 3. **Skill-Gap Analysis**: Identify missing qualifications to achieve desired job roles.
# 4. **Improving Recruitment Efficiency**: Assist employers in finding well-suited candidates.
#
# By leveraging **supervised and unsupervised learning techniques**, this dataset enables the development of an intelligent job recommendation system that improves job search efficiency and enhances the overall recruitment experience for both job seekers and employers.

# %% [markdown]
# # Source of the dataset

# %% [markdown]
# # General Information
# This dataset consists of 2000 rows and 8 columns
# The 8 columns are:
# 1-	Id
#
# 2-	careerjunction_za_courses,
#
# 3-	careerjunction_za_employer_names,
#
# 4-	careerjunction_za_future_jobtitles,
#
# 5-	careerjunction_za_historical_jobtitles,
#
# 6-	'careerjunction_za_primary_jobtitle,
#
# 7-	careerjunction_za_recent_jobtitles,
#
# 8-	careerjunction_za_skills.
#
#  The number of observations were 2000.
#  Number and type of variables:
# | Variable                              | Description                                                               | Variable Type   |
# |---------------------------------------|---------------------------------------------------------------------------|-----------------|
# | ID                                    | Unique identifier for the profile.                                        | String |
# | careerjunction_za_courses             | Titles for education/courses the profile has completed.                   | List of Strings|
# | careerjunction_za_employer_names      | All employers worked for.                                                 | List of Strings|
# | careerjunction_za_future_jobtitles    | Job titles the seeker would like to have as their next job.               | List of Strings|
# | careerjunction_za_historical_jobtitles|All other job titles after the recent ones (from the 4th job title onward).| List of Strings|
# | careerjunction_za_primary_jobtitle    | Most recent job title of the profile.                                     | String |
# | careerjunction_za_recent_jobtitles    | The next job titles after the most recent one (max 2).                    | List of Strings|
# | careerjunction_za_skills              | All the skills associated with the profile.                               | List of Strings|
#
# df.careerjunction_za_future_jobtitles.value_counts().head(10)
#
# []                          656
#
# [u'Software Developer']      24
#
# [u'Developer']               15
#
# [u'Java Developer']          13
#
# [u'Web Developer']            7
#
# [u'software developer']       6
#
# [u'Senior Developer']         5
#
# [u'Business Analyst']         5
#
# [u'Senior C# Developer']      4
#
# [u'Analyst']                  3
#
# •[] 656
#
# As we can see from the result above The value counts for careerjunction_za_future_jobtitles reveal that the most common future job title is an empty list ([]), which appears 656 times. This indicates that many profiles have not specified a future job title.

# %% [markdown]
# # Summary of the dataset

# %%
import pandas as pd

# 📌 إنشاء بيانات الجدول يدويًا
data = {
    "ID": [1, 2, 3, 4, 5],
    "careerjunction_za_courses": ["Python", "Data Science", "AI", "Machine Learning", "Deep Learning"],
    "careerjunction_za_employer_names": ["Google", "Amazon", "Microsoft", "Facebook", "Tesla"],
    "careerjunction_za_future_jobtitles": ["Data Scientist", "ML Engineer", "AI Researcher", "Software Engineer", "Research Scientist"],
    "careerjunction_za_historical_jobtitles": ["Intern", "Junior Developer", "Data Analyst", "Backend Engineer", "Research Assistant"],
    "careerjunction_za_primary_jobtitle": ["Software Engineer", "Data Engineer", "AI Engineer", "ML Engineer", "Deep Learning Engineer"],
    "careerjunction_za_recent_jobtitles": ["Senior Developer", "AI Consultant", "ML Specialist", "Data Lead", "AI Lead"],
    "careerjunction_za_skills": ["Python, SQL", "TensorFlow, PyTorch", "AI, ML", "Deep Learning", "Computer Vision"]
}

# 📌 تحويل البيانات إلى DataFrame
df_sample = pd.DataFrame(data)

# 📌 عرض الجدول
df_sample
# Out:
#    ID careerjunction_za_courses careerjunction_za_employer_names  \
# 0   1                    Python                           Google
# 1   2              Data Science                           Amazon
# 2   3                        AI                        Microsoft
# 3   4          Machine Learning                         Facebook
# 4   5             Deep Learning                            Tesla
#
#   careerjunction_za_future_jobtitles careerjunction_za_historical_jobtitles  \
# 0                     Data Scientist                                 Intern
# 1                        ML Engineer                       Junior Developer
# 2                      AI Researcher                           Data Analyst
# 3                  Software Engineer                       Backend Engineer
# 4                 Research Scientist                     Research Assistant
#
#   careerjunction_za_primary_jobtitle careerjunction_za_recent_jobtitles  \
# 0                  Software Engineer                   Senior Developer
# 1                      Data Engineer                      AI Consultant
# 2                        AI Engineer                      ML Specialist
# 3                        ML Engineer                          Data Lead
# 4             Deep Learning Engineer                            AI Lead
#
#   careerjunction_za_skills
# 0              Python, SQL
# 1      TensorFlow, PyTorch
# 2                   AI, ML
# 3            Deep Learning
# 4          Computer Vision

# %%
# Summary of the dataset
# 📌 استيراد المكتبات
import pandas as pd
import matplotlib.pyplot as plt

# 📌 إنشاء بيانات الجدول يدويًا (بدون الحاجة لتحميل ملف)
data = {
    "ID": [1, 2, 3, 4, 5],
    "careerjunction_za_courses": ["Python", "Data Science", "AI", "Machine Learning", "Deep Learning"],
    "careerjunction_za_employer_names": ["Google", "Amazon", "Microsoft", "Facebook", "Tesla"],
    "careerjunction_za_future_jobtitles": ["Data Scientist", "ML Engineer", "AI Researcher", "Software Engineer", "Research Scientist"],
    "careerjunction_za_primary_jobtitle": ["Software Engineer", "Data Engineer", "AI Engineer", "ML Engineer", "Deep Learning Engineer"],
    "careerjunction_za_skills": ["Python, SQL", "TensorFlow, PyTorch", "AI, ML", "Deep Learning", "Computer Vision"]
}

# 📌 تحويل البيانات إلى DataFrame
df_sample = pd.DataFrame(data)

# 📌 عرض البيانات
print("📌 Sample of the dataset:")
display(df_sample)

# 📌 البحث عن القيم المفقودة
missing_values = df_sample.isnull().sum()
print("\n📌 Missing Values Per Column:")
print(missing_values)

# 📌 الإحصائيات العامة للبيانات
print("\n📌 Statistical Summary:")
print(df_sample.describe(include="all"))

# 📌 رسم بياني: توزيع الوظائف المستقبلية
plt.figure(figsize=(8, 5))
df_sample["careerjunction_za_future_jobtitles"].value_counts().plot(kind="bar", color="skyblue", edgecolor="black")
plt.title("Distribution of Future Job Titles")
plt.xlabel("Job Titles")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# 📌 حساب عدد الكلمات في الدورات التدريبية
df_sample["word_count"] = df_sample["careerjunction_za_courses"].apply(lambda x: len(x.split()))

# 📌 رسم بياني: توزيع عدد الكلمات في الدورات التدريبية
plt.figure(figsize=(8, 5))
plt.hist(df_sample["word_count"], bins=5, color="blue", edgecolor="black")
plt.title("Word Count Distribution in Courses")
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.show()
# Out:
# 📌 Sample of the dataset:
#    ID careerjunction_za_courses careerjunction_za_employer_names  \
# 0   1                    Python                           Google
# 1   2              Data Science                           Amazon
# 2   3                        AI                        Microsoft
# 3   4          Machine Learning                         Facebook
# 4   5             Deep Learning                            Tesla
#
#   careerjunction_za_future_jobtitles careerjunction_za_primary_jobtitle  \
# 0                     Data Scientist                  Software Engineer
# 1                        ML Engineer                      Data Engineer
# 2                      AI Researcher                        AI Engineer
# 3                  Software Engineer                        ML Engineer
# 4                 Research Scientist             Deep Learning Engineer
#
#   careerjunction_za_skills
# 0              Python, SQL
# 1      TensorFlow, PyTorch
# 2                   AI, ML
# 3            Deep Learning
# 4          Computer Vision
# 📌 Missing Values Per Column:
# ID                                    0
# careerjunction_za_courses             0
# careerjunction_za_employer_names      0
# careerjunction_za_future_jobtitles    0
# careerjunction_za_primary_jobtitle    0
# careerjunction_za_skills              0
# dtype: int64
#
# 📌 Statistical Summary:
#               ID careerjunction_za_courses careerjunction_za_employer_names  \
# count   5.000000                         5                                5
# unique       NaN                         5                                5
# top          NaN                    Python                           Google
# freq         NaN                         1                                1
# mean    3.000000                       NaN                              NaN
# std     1.581139                       NaN                              NaN
# min     1.000000                       NaN                              NaN
# 25%     2.000000                       NaN                              NaN
# 50%     3.000000                       NaN                              NaN
# 75%     4.000000                       NaN                              NaN
# max     5.000000                       NaN                              NaN
#
#        careerjunction_za_future_jobtitles careerjunction_za_primary_jobtitle  \
# count                                   5                                  5
# unique                                  5                                  5
# top                        Data Scientist                  Software Engineer
# freq                                    1                                  1
# mean                                  NaN                                NaN
# std                                   NaN                                NaN
# min                                   NaN                                NaN
# 25%                                   NaN                                NaN
# 50%                                   NaN                                NaN
# 75%                                   NaN                                NaN
# max                                   NaN                                NaN
#
#        careerjunction_za_skills
# count                         5
# unique                        5
# top                 Python, SQL
# freq                          1
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %% [markdown]
# # Preprocessing techniques
